# %%
import numpy as np
import matplotlib.pyplot as plt
name = 'horizons_2010CO1'
#mpc
f = open(name+'.txt',"r")
lines = f.readlines()
i=0
mpcdata = []
for line in lines:
    if (i%4 == 1): 
        mpcdata.append(line.split())
    i+=1
f.close()
mpcdata = np.float64(mpcdata)
len(mpcdata)
# Out:
# 15

# %%
dat = np.loadtxt('nea.dat.2010CO1')
dat = dat[:15,1:4]

# %%
plt.plot(mpcdata[0,:])
plt.plot(dat[0,:])
