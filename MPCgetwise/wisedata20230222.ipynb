# %% [markdown]
# ## 对最后的统计结果（pha，wise）处理

# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from requests.api import request
from tqdm import tqdm
raw_data = pd.read_table('wisefinal_hv.txt')
raw_mpc = pd.read_table('mpc_raw.txt')
raw_mpc
# Out:
#       Number        Name       Desig  Family CS Class DS  DF   Diam HS  ...  \
# 0          0     1991 VA     1991 VA  9101.0  A    S*  D NaN  0.017  L  ...
# 1          0    1994 CJ1    1994 CJ1  9101.0  A    S*  C NaN  0.156  M  ...
# 2          0     1995 CR     1995 CR  9101.0  A    S*  C NaN  0.130  M  ...
# 3          0     1995 HM     1995 HM  9101.0  A    S*  D NaN  0.094  L  ...
# 4          0     1996 GQ     1996 GQ  9101.0  A    S*  C NaN  0.071  M  ...
# ...      ...         ...         ...     ... ..   ... ..  ..    ... ..  ...
# 1310  530520   2011 LT17   2011 LT17  9101.0  A    S*  C NaN  0.134  M  ...
# 1311  533011   2014 AY28   2014 AY28  9101.0  A    S*  C NaN  0.122  L  ...
# 1312  533990  2014 QX266  2014 QX266  9101.0  A    S*  C NaN  0.091  T  ...
# 1313  535844  2015 BY310  2015 BY310  9101.0  A    S*  C NaN  0.130  T  ...
# 1314  554126     2012 NP     2012 NP  9101.0  A    S*  C NaN  0.160  M  ...
#
# ...

# %%
data = raw_data[231:]
da = raw_mpc[['Name','Diam','H',]]
data
# Out:
#            Name   Diam Class      H  time
# 231      Derm4c  0.103    S*  22.31     0
# 232      Derm1a  0.079    S*  22.88     0
# 233      Derm1c  0.133    S*  21.74     0
# 234      Derm0f  0.135    S*  21.71     0
# 235   93P/Lovas    NaN   NaN    NaN     0
# ...         ...    ...   ...    ...   ...
# 1310  2013 PH10  0.065    S*  23.30    -1
# 1311   2013 PC7  0.098    S*  22.40    -1
# 1312   2013 NQ8  0.118    S*  22.00    -1
# 1313    2013 NJ  0.104    S*  22.27    -1
# 1314    2012 NP  0.160    S*  21.34    -1
#
# [1084 rows x 5 columns]

# %%
data2 = data.sort_values(by=['Diam'],ascending=False,ignore_index=True)
data2.to_csv('wisehvdate20230222.txt',sep='\t')
