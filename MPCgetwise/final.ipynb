# %% [markdown]
# ## 对最后的统计结果（pha，wise）处理

# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from requests.api import request
from tqdm import tqdm
raw_data = pd.read_table('mpc_final_sort.txt')
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
data = raw_data[:230]
data
# Out:
#            Name   Diam    type          PHA  time
# 0      2019 NC1  0.137    Aten         Near  2021
# 1       2020 MV  0.062  Apollo         Near  2020
# 2      2020 QU4  0.142    Amor         Near  2020
# 3      2020 BJ4  0.124  Apollo  Potentially  2020
# 4     2020 BN11  0.090  Apollo         Near  2020
# ..          ...    ...     ...          ...   ...
# 225    2010 KX7  0.124    Aten  Potentially  2010
# 226  2010 HX107  0.057    Aten         Near  2010
# 227   2009 UX17  0.149    Amor         Near  2010
# 228   2010 HW81  0.156  Apollo         Near  2010
# 229    2000 AA6  0.113  Apollo         Near  2010
#
# [230 rows x 5 columns]

# %%
pha = data['PHA'].value_counts()
wise = data['time'].value_counts()
type = data['type'].value_counts()
print(pha,'\n\n',wise,'\n\n',type)
# Out:
# Near           178
# Potentially     49
# -1               3
# Name: PHA, dtype: int64
#
#  2010    55
# 2016    44
# 2015    30
# 2017    26
# 2014    25
# 2018    18
# 2019    15
# 2020    13
# 2013     2
# 2021     1
# 2011     1
# Name: time, dtype: int64
#
#  Apollo    161
# Amor       42
# Aten       24
# Main        3
# Name: type, dtype: int64

# %%
data2 = data.sort_values(by=['PHA','time','Diam'],ascending=False,ignore_index=True)
data3 = data2[:49]
data3.to_csv('pha.txt',sep='\t')
data4 = data.sort_values(by=['Diam'],ascending=False,ignore_index=True)
data5 = data4[105:230]
data5 = data5.sort_values(by=['time','Diam'],ascending=True,ignore_index=True)
data5[0:50]
# Out:
#           Name   Diam    type   PHA  time
# 0   2010 BH115  0.000    Main    -1  2010
# 1    2010 JX16  0.000    Main    -1  2010
# 2    2010 NS36  0.000    Main    -1  2010
# 3    2010 EX11  0.045    Aten  Near  2010
# 4     2010 MY1  0.049  Apollo  Near  2010
# 5     2010 FE7  0.054  Apollo  Near  2010
# 6   2010 HX107  0.057    Aten  Near  2010
# 7    2010 KP10  0.062  Apollo  Near  2010
# 8    2010 FG81  0.065    Amor  Near  2010
# 9      1996 GQ  0.071    Amor  Near  2010
# 10   2010 LL68  0.078  Apollo  Near  2010
# 11    2008 NP3  0.081  Apollo  Near  2010
# 12   2010 AJ30  0.084    Aten  Near  2010
# 13   2010 CB55  0.086  Apollo  Near  2010
# 14  2016 UH101  0.086  Apollo  Near  2010
# 15   2010 LJ68  0.086  Apollo  Near  2010
# 16  2010 LV108  0.090    Amor  Near  2010
# 17   2010 CC55  0.094  Apollo  Near  2010
# 18   2010 LK68  0.094  Apollo  Near  2010
# 19  2010 HZ104  0.094  Apollo  Near  2010
# 20   2010 GP67  0.094  Apollo  Near  2010
# ...
