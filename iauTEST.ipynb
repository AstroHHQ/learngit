# %% [markdown]
# ## 抓取MPC上小行星的数据
# 作者：AstroHHQ

# %% [markdown]
# ### selenium 实现

# %%
from selenium import webdriver
import time
import json
import pandas as pd

# %% [markdown]
# ### request 实现

# %%
#load import
import numpy as np
import pandas as pd
from urllib.request import urlopen
from requests.api import request

mpcdata = pd.read_table('mpc.txt')
#mpcdata.sort_values('Diam',ascending=False)
sort_data = mpcdata.sort_values('Diam',ascending=False)
#mpcdata['Name'][0]
mp_name = mpcdata["Name"][:]
print(mp_name[0])
# Out:
# 1991 VA

# %%
#space to "+"
name = mp_name[599]
name = name.replace(' ','+')

# %%
#get the html 
#url='https://irsa.ipac.caltech.edu/workspace/TMP_1xtVlX_10857/Gator/irsa/30071/tbview.html'
url = f'https://minorplanetcenter.net/db_search/show_object?utf8=%E2%9C%93&object_id={name}'
import requests as rq
head ={
    'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
}
resp = rq.get(url,headers=head)

# %%
mptable = pd.read_html(resp.text)[7]
mptable
# Out:
#             Date (UT)     J2000 RA    J2000 Dec    Magn  \
# 0    2014 11 04.22197  04 58 49.94  +44 55 29.5  19.4 R
# 1    2014 11 04.22390  04 58 51.00  +44 55 20.1  19.3 R
# 2    2014 11 04.22583  04 58 52.17  +44 55 08.8  19.2 R
# 3    2014 11 04.22776  04 58 53.29  +44 54 59.0  19.3 R
# 4    2014 11 04.22969  04 58 54.37  +44 54 49.1  19.4 R
# 5    2014 11 04.23163  04 58 55.56  +44 54 38.2  19.4 R
# 6    2014 11 04.45866  05 01 15.06  +44 34 47.9  20.2 R
# 7    2014 11 04.45936  05 01 15.46  +44 34 44.1  20.3 R
# 8    2014 11 04.46005  05 01 15.88  +44 34 40.4  20.6 R
# 9    2014 11 04.81811  05 05 02.47  +44 01 19.0     NaN
# 10   2014 11 04.85409  05 05 24.35  +43 58 05.4     NaN
# 11   2014 11 05.51692  05 12 07.96  +42 53 56.7  19.9 V
# 12   2014 11 05.51721  05 12 08.07  +42 53 55.4  19.9 V
# 13   2014 11 05.51777  05 12 08.25  +42 53 52.7  19.8 V
# 14   2014 11 05.51807  05 12 08.43  +42 53 50.7  19.6 V
# 15   2014 11 05.92689  05 16 33.22  +42 10 35.2  20.0 R
# 16   2014 11 05.96937  05 16 59.41  +42 06 08.7  19.2 R
# 17   2014 11 06.02148  05 17 31.19  +42 00 35.9     NaN
# 18   2014 11 06.04245  05 17 43.98  +41 58 21.3  19.6 R
# 19   2014 11 06.25088  05 19 50.44  +41 35 48.3  19.9 R
# 20   2014 11 06.25154  05 19 50.92  +41 35 43.4  19.5 R
# 21   2014 11 06.25538  05 19 53.24  +41 35 17.0  20.0 R
# 22   2014 11 06.25655  05 19 53.87  +41 35 08.4  19.6 R
# 23   2014 11 06.25921  05 19 55.56  +41 34 50.7  19.6 R
# 24   2014 11 06.26033  05 19 56.13  +41 34 42.7  19.5 R
# 25   2014 11 06.26305  05 19 57.88  +41 34 24.1  19.5 R
# 26   2014 11 06.26691  05 20 00.23  +41 33 57.4  19.2 R
# 27   2014 11 06.27075  05 20 02.54  +41 33 31.1  19.3 R
# 28   2014 11 06.27460  05 20 04.89  +41 33 04.4  19.2 R
# 29   2014 11 06.27846  05 20 07.23  +41 32 37.7  19.2 R
# 30  2014 11 14.340352  06 46 47.85  +18 25 12.3  19.2 V
# 31  2014 11 14.343293  06 46 49.56  +18 24 32.2  19.1 V
# 32  2014 11 14.346234  06 46 51.30  +18 23 51.9  19.4 V
# 33  2014 11 14.349121  06 46 52.98  +18 23 12.8  19.1 V
# 34  2014 11 14.351895  06 46 54.61  +18 22 34.8  19.4 V
# 35   2014 11 14.95868  06 53 11.76  +16 02 20.0  19.0 V
# 36   2014 11 14.97233  06 53 19.89  +15 59 10.1  19.0 V
# 37   2014 11 15.04112  06 54 03.61  +15 43 41.2  18.1 R
# 38   2014 11 15.04182  06 54 04.03  +15 43 31.9  19.1 R
# 39   2014 11 15.04251  06 54 04.44  +15 43 21.7  18.9 R
# 40   2014 11 15.04320  06 54 04.85  +15 43 12.2  18.9 R
# 41   2014 11 15.04389  06 54 05.26  +15 43 02.3  19.0 R
# 42   2014 11 15.04458  06 54 05.66  +15 42 52.9  19.1 R
# 43   2014 11 15.04528  06 54 06.10  +15 42 42.8  19.3 R
# 44   2014 11 15.04596  06 54 06.48  +15 42 33.7  18.7 R
# 45   2014 11 15.04665  06 54 06.89  +15 42 24.1  19.0 R
# 46   2014 11 15.04735  06 54 07.28  +15 42 14.4  18.3 R
# 47   2014 11 15.04839  06 54 07.90  +15 41 59.8  19.0 R
# 48   2014 11 15.04908  06 54 08.31  +15 41 50.3  18.7 R
# 49  2014 11 18.384580  07 26 31.55  +02 25 13.1  19.1 V
# 50  2014 11 18.386389  07 26 32.46  +02 24 47.7  19.7 V
# 51  2014 11 18.388271  07 26 33.44  +02 24 21.0  20.1 V
# 52  2014 11 18.390151  07 26 34.41  +02 23 54.4  19.8 V
# 53  2014 11 18.392033  07 26 35.39  +02 23 27.2     NaN
# 54  2014 11 18.393917  07 26 36.34  +02 23 00.5     NaN
# 55  2014 11 18.395800  07 26 37.30  +02 22 33.7     NaN
# 56  2014 11 18.397493  07 26 38.21  +02 22 09.8  19.6 V
# 57  2014 11 21.423364  07 53 01.42  -08 59 42.4  20.0 V
# 58  2014 11 21.425150  07 53 02.24  -09 00 04.8  20.0 V
# 59  2014 11 21.428721  07 53 03.83  -09 00 50.1  20.1 V
#
#                                              Location         Ref
# 0                                      950 – La Palma  MPS 544906
# 1                                      950 – La Palma  MPS 544906
# 2                                      950 – La Palma  MPS 544906
# 3                                      950 – La Palma  MPS 544906
# 4                                      950 – La Palma  MPS 544906
# 5                                      950 – La Palma  MPS 544906
# 6                             291 – LPL/Spacewatch II  MPS 544906
# 7                             291 – LPL/Spacewatch II  MPS 544906
# 8                             291 – LPL/Spacewatch II  MPS 544906
# 9   118 – Astronomical and Geophysical Observatory...  MPS 545885
# 10  118 – Astronomical and Geophysical Observatory...  MPS 545885
# 11                   648 – Winer Observatory, Sonoita  MPS 544906
# 12                   648 – Winer Observatory, Sonoita  MPS 544906
# 13                   648 – Winer Observatory, Sonoita  MPS 544906
# 14                   648 – Winer Observatory, Sonoita  MPS 544906
# 15                               J95 – Great Shefford  MPS 544906
# 16                               J95 – Great Shefford  MPS 544906
# 17                               J95 – Great Shefford  MPS 544906
# 18                               J95 – Great Shefford  MPS 544906
# 19                            954 – Teide Observatory  MPS 544906
# 20                                     950 – La Palma  MPS 544906
# 21                                     950 – La Palma  MPS 544906
# 22                            954 – Teide Observatory  MPS 544906
# 23                                     950 – La Palma  MPS 544906
# 24                            954 – Teide Observatory  MPS 544906
# 25                                     950 – La Palma  MPS 544906
# 26                                     950 – La Palma  MPS 544906
# 27                                     950 – La Palma  MPS 544906
# 28                                     950 – La Palma  MPS 544906
# 29                                     950 – La Palma  MPS 544906
# 30  H21 – Astronomical Research Observatory, Westf...  MPS 544906
# 31  H21 – Astronomical Research Observatory, Westf...  MPS 544906
# 32  H21 – Astronomical Research Observatory, Westf...  MPS 544906
# 33  H21 – Astronomical Research Observatory, Westf...  MPS 544906
# 34  H21 – Astronomical Research Observatory, Westf...  MPS 544906
# 35   033 – Karl Schwarzschild Observatory, Tautenburg  MPS 545885
# 36   033 – Karl Schwarzschild Observatory, Tautenburg  MPS 545885
# 37                                     950 – La Palma  MPS 545885
# 38                                     950 – La Palma  MPS 545885
# 39                                     950 – La Palma  MPS 545885
# 40                                     950 – La Palma  MPS 545885
# 41                                     950 – La Palma  MPS 545885
# 42                                     950 – La Palma  MPS 545885
# 43                                     950 – La Palma  MPS 545885
# 44                                     950 – La Palma  MPS 545885
# 45                                     950 – La Palma  MPS 545885
# 46                                     950 – La Palma  MPS 545885
# 47                                     950 – La Palma  MPS 545885
# 48                                     950 – La Palma  MPS 545885
# 49  H21 – Astronomical Research Observatory, Westf...  MPS 545885
# 50  H21 – Astronomical Research Observatory, Westf...  MPS 545885
# 51  H21 – Astronomical Research Observatory, Westf...  MPS 545885
# 52  H21 – Astronomical Research Observatory, Westf...  MPS 545885
# 53  H21 – Astronomical Research Observatory, Westf...  MPS 545885
# 54  H21 – Astronomical Research Observatory, Westf...  MPS 545885
# 55  H21 – Astronomical Research Observatory, Westf...  MPS 545885
# 56  H21 – Astronomical Research Observatory, Westf...  MPS 545885
# 57  H21 – Astronomical Research Observatory, Westf...  MPS 547961
# 58  H21 – Astronomical Research Observatory, Westf...  MPS 547961
# 59  H21 – Astronomical Research Observatory, Westf...  MPS 547961

# %%
df = mptable
dfyes = df[df['Location']=='C51 – WISE']
dfyes["Date (UT)"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2323429/2032510637.py in <module>
#       1 df = mptable
# ----> 2 dfyes = df[df['Location']=='C51 – WISE']
#       3 dfyes["Date (UT)"]
#
# TypeError: list indices must be integers or slices, not str
